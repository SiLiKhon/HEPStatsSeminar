# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import uproot

from sklearn.metrics import roc_auc_score

# %%
tree = uproot.open("global_train.root")['tree']

# %%
tree.keys()
# Out:
# [b'VeloCharge',
#  b'BremPIDe',
#  b'CaloNeutralPrs',
#  b'CaloNeutralSpd',
#  b'InAccBrem',
#  b'InAccSpd',
#  b'CaloPrsE',
#  b'InAccPrs',
#  b'HcalPIDe',
#  b'CaloHcalE',
#  b'InAccHcal',
#  b'CaloTrajectoryL',
#  b'EcalPIDe',
#  b'CaloNeutralEcal',
#  b'CaloTrMatch',
#  b'CaloElectronMatch',
#  b'CaloChargedPrs',
#  b'CaloChargedSpd',
#  b'MuonNShared',
#  b'CaloBremMatch',
#  b'MuonIsLooseMuon',
#  b'MuonIsMuon',
#  b'MuonBkgLL',
#  b'InAccEcal',
#  b'MuonMuLL',
#  b'TrackMatchChi2',
#  b'TrackGhostProbability',
#  b'TrackType',
#  b'EcalPIDmu',
#  b'TrackPt',
#  b'TrackP',
#  b'NumProtoParticles',
#  b'RichAboveMuThres',
#  b'NumCaloHypos',
#  b'InAccMuon',
#  b'TrackChi2PerDof',
#  b'TrackNumDof',
#  b'NumUpstreamTracks',
#  b'NumLongTracks',
#  b'NumDownstreamTracks',
#  b'CaloEcalChi2',
#  b'NumRich1Hits',
#  b'NumMuonTracks',
#  b'CombDLLmu',
#  b'CaloSpdE',
#  b'PrsPIDe',
#  b'HcalPIDmu',
#  b'NumSPDHits',
#  b'NumVeloTracks',
#  b'NumTTracks',
#  b'TrackFitMatchChi2',
#  b'CombDLLpi',
#  b'RichDLLbt',
#  b'TrackHistory',
#  b'RichDLLpi',
#  b'TrackCloneDist',
#  b'TrackFitVeloNDoF',
#  b'NumPVs',
#  b'CombDLLp',
#  b'TrackFitTChi2',
#  b'TrackFitTNDoF',
#  b'RichAboveElThres',
#  b'RichUsedAero',
#  b'TrackDOCA',
#  b'RichDLLe',
#  b'TrackLikelihood',
#  b'CombDLLe',
#  b'CombDLLk',
#  b'CaloClusChi2',
#  b'TrackFitVeloChi2',
#  b'RichDLLp',
#  b'RichUsedR1Gas',
#  b'CaloBremChi2',
#  b'RichUsedR2Gas',
#  b'CaloEcalE',
#  b'RichAbovePiThres',
#  b'CaloChargedEcal',
#  b'NumRich2Hits',
#  b'RichAboveKaThres',
#  b'RichAbovePrThres',
#  b'RichDLLmu',
#  b'RichDLLk',
#  b'RecoPIDcode',
#  b'HasMC',
#  b'MCParticleType',
#  b'MCParticleP',
#  b'MCParticlePt',
#  b'MCVirtualMass',
#  b'MCFromB',
#  b'MCFromD',
#  b'MCVertexType',
#  b'MCVertexX',
#  b'MCVertexY',
#  b'MCVertexZ',
#  b'piplus_OWNPV_X',
#  b'piplus_OWNPV_Y',
#  b'piplus_OWNPV_Z',
#  b'piplus_OWNPV_XERR',
#  b'piplus_OWNPV_YERR',
#  b'piplus_OWNPV_ZERR',
#  b'piplus_OWNPV_CHI2',
#  b'piplus_OWNPV_NDOF',
#  b'piplus_IP_OWNPV',
#  b'piplus_IPCHI2_OWNPV',
#  b'nCandidate',
#  b'totCandidates',
#  b'EventInSequence']

# %%
pdg_id = tree.array('MCParticleType')

# %%
sel = (np.abs(pdg_id) == 321) | (np.abs(pdg_id) == 211)

# %%
def get_feature(key):
    return tree.array(key)[sel]

# %%
is_k = np.abs(get_feature('MCParticleType')) == 321

# %%
from tqdm import tqdm_notebook as tqdm

# %%
scores = {key : roc_auc_score(is_k, get_feature(key)) for key in tqdm(tree.keys())
              if b'MC' not in key and
                 b'Comb' not in key}
# Out:
# HBox(children=(IntProgress(value=0, max=107), HTML(value='')))

# %%
best20 = sorted(scores.items(), key=lambda x: max(x[1], 1. - x[1]))[-20:]

# %%
from itertools import combinations_with_replacement as combwr

# %%
scores_2 = {
    tuple(sorted((f1, f2))) : roc_auc_score(is_k, get_feature(f1) * get_feature(f2))
        for f1, f2 in tqdm(combwr(list(zip(*best20))[0], 2))
}
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
sorted(scores_2.items(), key=lambda x: -max(x[1], 1. - x[1]))
# Out:
# [((b'RichAbovePiThres', b'RichDLLk'), 0.9463163060455513),
#  ((b'RichDLLk', b'VeloCharge'), 0.9363588742862012),
#  ((b'RichDLLk', b'TrackPt'), 0.9356572255385232),
#  ((b'RichDLLk', b'TrackFitTNDoF'), 0.9340715547107858),
#  ((b'RichDLLk', b'TrackHistory'), 0.9323486587628173),
#  ((b'RichDLLk', b'TrackP'), 0.9301782541798217),
#  ((b'RichDLLk', b'TrackLikelihood'), 0.07355534118743048),
#  ((b'InAccMuon', b'RichDLLk'), 0.9256574149367924),
#  ((b'RichDLLk', b'TrackGhostProbability'), 0.913155653381006),
#  ((b'RichDLLk', b'piplus_IP_OWNPV'), 0.9111231405324076),
#  ((b'RichAbovePiThres', b'RichDLLbt'), 0.9033755640585059),
#  ((b'RichAbovePiThres', b'RichDLLp'), 0.9003389261957406),
#  ((b'RichDLLbt', b'VeloCharge'), 0.8952844633195653),
#  ((b'RichDLLbt', b'TrackFitTNDoF'), 0.8949199436120304),
#  ((b'RichDLLbt', b'TrackHistory'), 0.8925229110388972),
#  ((b'RichDLLp', b'VeloCharge'), 0.8924522955942784),
#  ((b'RichDLLp', b'TrackFitTNDoF'), 0.891647454831904),
#  ((b'RichDLLp', b'TrackHistory'), 0.8894115869469426),
#  ((b'RichDLLbt', b'TrackLikelihood'), 0.11387604764283042),
#  ((b'InAccMuon', b'RichDLLbt'), 0.8860176848588972),
#  ((b'RichDLLp', b'TrackLikelihood'), 0.11701904239545714),
#  ((b'InAccMuon', b'RichDLLp'), 0.8821123553864041),
#  ((b'RichDLLbt', b'TrackPt'), 0.8791521959651203),
#  ((b'RichDLLp', b'TrackPt'), 0.874875950152195),
#  ((b'RichDLLbt', b'TrackGhostProbability'), 0.871948340229962),
#  ((b'RichDLLbt', b'piplus_IP_OWNPV'), 0.8713707009202984),
#  ((b'RichDLLp', b'TrackGhostProbability'), 0.8696562162672419),
#  ((b'RichDLLp', b'piplus_IP_OWNPV'), 0.8689179302719248),
#  ((b'RichDLLbt', b'TrackP'), 0.8675921928651317),
#  ((b'RichDLLp', b'TrackP'), 0.863310206726466),
#  ((b'RichDLLk', b'RichUsedR2Gas'), 0.8420976859205542),
#  ((b'RichDLLe', b'RichDLLk'), 0.1753515903239551),
#  ((b'RichDLLbt', b'RichDLLe'), 0.19388385578449896),
#  ((b'RichDLLe', b'RichDLLp'), 0.1969912148654885),
#  ((b'CaloEcalE', b'RichDLLk'), 0.7935099803063078),
#  ((b'RichAboveKaThres', b'RichDLLk'), 0.791125503771731),
#  ((b'RichDLLbt', b'RichUsedR2Gas'), 0.784664492165948),
#  ((b'RichDLLp', b'RichUsedR2Gas'), 0.7801573393881059),
#  ((b'CaloHcalE', b'RichDLLk'), 0.7773547595749083),
#  ((b'CaloEcalE', b'RichDLLbt'), 0.7709473710677507),
#  ((b'RichDLLk', b'RichDLLmu'), 0.23101023086743327),
#  ((b'CaloEcalE', b'RichDLLp'), 0.7667617306714347),
#  ((b'RichDLLe', b'VeloCharge'), 0.7571086622359608),
#  ((b'RichDLLbt', b'RichDLLmu'), 0.24818237814130176),
#  ((b'CaloHcalE', b'RichDLLbt'), 0.7506670283755565),
#  ((b'RichDLLmu', b'RichDLLp'), 0.2514530673966284),
#  ((b'RichDLLe', b'RichDLLe'), 0.252590386188495),
#  ((b'RichDLLe', b'TrackFitTNDoF'), 0.7456587875091053),
#  ((b'CaloHcalE', b'RichDLLp'), 0.7441839274846834),
#  ((b'RichDLLe', b'TrackHistory'), 0.738832485833517),
#  ((b'RichDLLe', b'TrackP'), 0.7325888783846474),
#  ((b'RichDLLe', b'piplus_IP_OWNPV'), 0.7316935127187438),
#  ((b'RichDLLe', b'TrackLikelihood'), 0.26990962818946446),
#  ((b'RichAboveKaThres', b'RichDLLbt'), 0.7259236633761521),
#  ((b'RichAboveKaThres', b'RichDLLp'), 0.7205541667659299),
#  ((b'RichDLLe', b'TrackGhostProbability'), 0.7181638668255298),
#  ((b'RichAbovePiThres', b'RichDLLe'), 0.7122411886441029),
#  ((b'InAccMuon', b'RichDLLe'), 0.6976237622995625),
#  ((b'RichDLLe', b'TrackPt'), 0.6921671714957424),
#  ((b'RichDLLe', b'RichDLLmu'), 0.3194005087869235),
#  ((b'RichDLLmu', b'VeloCharge'), 0.6737081937314896),
#  ((b'RichDLLmu', b'TrackFitTNDoF'), 0.6675314297749659),
#  ((b'RichDLLmu', b'RichDLLmu'), 0.33520943581351464),
#  ((b'RichDLLmu', b'TrackHistory'), 0.6641554108978054),
#  ((b'RichDLLmu', b'piplus_IP_OWNPV'), 0.6617235430558355),
#  ((b'RichDLLmu', b'TrackLikelihood'), 0.3410170486618712),
#  ((b'RichDLLmu', b'TrackP'), 0.6553295877331116),
#  ((b'RichAbovePiThres', b'RichDLLmu'), 0.6548975509055567),
#  ((b'RichDLLmu', b'TrackGhostProbability'), 0.6511331181704657),
#  ((b'TrackP', b'TrackPt'), 0.6504369791852975),
#  ((b'TrackPt', b'TrackPt'), 0.6500972950625992),
#  ((b'RichAbovePiThres', b'TrackPt'), 0.648810772778523),
#  ((b'RichAbovePrThres', b'RichDLLk'), 0.6441972563923125),
#  ((b'TrackPt', b'VeloCharge'), 0.6418323042942614),
#  ((b'InAccMuon', b'RichDLLmu'), 0.6413897454866838),
#  ((b'TrackFitTNDoF', b'TrackPt'), 0.6277572943811601),
#  ((b'RichDLLmu', b'TrackPt'), 0.6276347894686501),
#  ((b'InAccMuon', b'TrackPt'), 0.6276113933877532),
#  ((b'TrackFitTNDoF', b'TrackP'), 0.6198818567498917),
#  ((b'TrackP', b'TrackP'), 0.619544817195338),
#  ((b'TrackHistory', b'TrackPt'), 0.6184281215280956),
#  ((b'RichAbovePiThres', b'TrackP'), 0.61806743101289),
#  ((b'TrackP', b'VeloCharge'), 0.6131567806080334),
#  ((b'CaloEcalE', b'RichDLLe'), 0.6130497828995309),
#  ((b'TrackHistory', b'TrackP'), 0.6060632262671808),
#  ((b'RichAboveKaThres', b'TrackPt'), 0.6048002220481238),
#  ((b'RichUsedR2Gas', b'TrackPt'), 0.6038782306355936),
#  ((b'TrackLikelihood', b'TrackPt'), 0.3973542451859341),
#  ((b'InAccMuon', b'TrackP'), 0.6000718808680839),
#  ((b'TrackLikelihood', b'TrackP'), 0.4019225261574071),
#  ((b'RichAboveKaThres', b'TrackP'), 0.596034160602194),
#  ((b'RichUsedR2Gas', b'TrackP'), 0.5910843322011579),
#  ((b'RichAboveKaThres', b'TrackFitTNDoF'), 0.5901112203400051),
#  ((b'CaloEcalE', b'RichDLLmu'), 0.5894444919097486),
#  ((b'RichAboveKaThres', b'TrackLikelihood'), 0.41099409653185814),
#  ((b'RichAboveKaThres', b'TrackHistory'), 0.5886632095179334),
#  ((b'RichAboveKaThres', b'RichAbovePiThres'), 0.5879837296084249),
#  ((b'RichAboveKaThres', b'RichAboveKaThres'), 0.5879837296084249),
#  ((b'CaloHcalE', b'RichDLLe'), 0.5879007444599361),
#  ((b'RichAboveKaThres', b'TrackGhostProbability'), 0.5856344318570286),
#  ((b'RichAboveKaThres', b'piplus_IP_OWNPV'), 0.584395298316843),
#  ((b'RichAboveKaThres', b'VeloCharge'), 0.5835373288678375),
#  ((b'InAccMuon', b'RichAboveKaThres'), 0.5809085422374404),
#  ((b'RichAboveKaThres', b'RichUsedR2Gas'), 0.579266548819878),
#  ((b'RichAbovePrThres', b'RichDLLbt'), 0.5783906022683947),
#  ((b'RichAbovePrThres', b'RichDLLp'), 0.5721251757902052),
#  ((b'RichUsedR2Gas', b'TrackFitTNDoF'), 0.5720072311482555),
#  ((b'RichUsedR2Gas', b'TrackLikelihood'), 0.4289222984468131),
#  ((b'RichUsedR2Gas', b'RichUsedR2Gas'), 0.5692100279144348),
#  ((b'RichAbovePiThres', b'RichUsedR2Gas'), 0.5692095279044347),
#  ((b'RichUsedR2Gas', b'TrackHistory'), 0.5690953906982927),
#  ((b'RichDLLe', b'RichUsedR2Gas'), 0.5679858242751799),
#  ((b'TrackGhostProbability', b'TrackPt'), 0.565218645873385),
#  ((b'TrackFitTNDoF', b'piplus_IP_OWNPV'), 0.43492534966361646),
#  ((b'TrackHistory', b'piplus_IP_OWNPV'), 0.43515995153472836),
#  ((b'CaloHcalE', b'RichDLLmu'), 0.5636292362689087),
#  ((b'InAccMuon', b'RichUsedR2Gas'), 0.5634708832015489),
#  ((b'VeloCharge', b'piplus_IP_OWNPV'), 0.43694991975027175),
#  ((b'RichUsedR2Gas', b'TrackGhostProbability'), 0.5624616113487348),
#  ((b'TrackLikelihood', b'piplus_IP_OWNPV'), 0.5614000194545982),
#  ((b'RichAbovePrThres', b'TrackPt'), 0.5608761003241571),
#  ((b'piplus_IP_OWNPV', b'piplus_IP_OWNPV'), 0.4398925544300299),
#  ((b'RichUsedR2Gas', b'VeloCharge'), 0.5595490551860564),
#  ((b'RichAbovePrThres', b'TrackP'), 0.5594832516752499),
#  ((b'TrackGhostProbability', b'piplus_IP_OWNPV'), 0.44086872315123965),
#  ((b'RichAbovePrThres', b'TrackFitTNDoF'), 0.5590719394419205),
#  ((b'RichAbovePrThres', b'TrackLikelihood'), 0.44118978683931676),
#  ((b'RichAbovePrThres', b'TrackHistory'), 0.5587783265412952),
#  ((b'RichAbovePrThres', b'piplus_IP_OWNPV'), 0.5585776970781573),
#  ((b'RichAbovePiThres', b'RichAbovePrThres'), 0.5585727169466771),
#  ((b'RichAbovePrThres', b'RichAbovePrThres'), 0.5585727169466771),
#  ((b'RichAboveKaThres', b'RichAbovePrThres'), 0.5585727169466771),
#  ((b'RichAbovePrThres', b'TrackGhostProbability'), 0.5581933052062493),
#  ((b'RichAbovePrThres', b'VeloCharge'), 0.5579965664360023),
#  ((b'RichUsedR2Gas', b'piplus_IP_OWNPV'), 0.5571336795010791),
#  ((b'RichAbovePrThres', b'RichUsedR2Gas'), 0.5566001786665559),
#  ((b'TrackGhostProbability', b'TrackP'), 0.5562768869062505),
#  ((b'InAccMuon', b'RichAbovePrThres'), 0.5529575940838184),
#  ((b'RichDLLk', b'RichDLLk'), 0.5472608814358664),
#  ((b'CaloEcalE', b'TrackPt'), 0.5454963718382827),
#  ((b'RichAbovePrThres', b'RichDLLmu'), 0.45452425538134555),
#  ((b'CaloEcalE', b'RichAboveKaThres'), 0.541892764432524),
#  ((b'TrackFitTNDoF', b'VeloCharge'), 0.45871603132679734),
#  ((b'TrackHistory', b'VeloCharge'), 0.46097148205184285),
#  ((b'CaloHcalE', b'RichAboveKaThres'), 0.5385801575332779),
#  ((b'CaloHcalE', b'TrackPt'), 0.5384851636752799),
#  ((b'InAccMuon', b'RichAbovePiThres'), 0.5380538338244321),
#  ((b'RichAbovePrThres', b'RichDLLe'), 0.46262260532653554),
#  ((b'TrackPt', b'piplus_IP_OWNPV'), 0.5355076751301664),
#  ((b'CaloEcalE', b'TrackP'), 0.5352783688693504),
#  ((b'RichAbovePiThres', b'RichAbovePiThres'), 0.5348494285128922),
#  ((b'TrackGhostProbability', b'TrackHistory'), 0.46520425436279306),
#  ((b'TrackFitTNDoF', b'TrackHistory'), 0.4656971502372095),
#  ((b'CaloEcalE', b'RichUsedR2Gas'), 0.5330678442047332),
#  ((b'VeloCharge', b'VeloCharge'), 0.4670811986573161),
#  ((b'TrackFitTNDoF', b'TrackGhostProbability'), 0.4674225618711935),
#  ((b'CaloHcalE', b'TrackFitTNDoF'), 0.5314337689670892),
#  ((b'TrackGhostProbability', b'VeloCharge'), 0.46891940860060316),
#  ((b'CaloHcalE', b'TrackP'), 0.5306102680785537),
#  ((b'TrackFitTNDoF', b'TrackFitTNDoF'), 0.47014149356823953),
#  ((b'CaloHcalE', b'RichUsedR2Gas'), 0.5283213774085669),
#  ((b'CaloHcalE', b'TrackLikelihood'), 0.4717355905709034),
#  ((b'TrackHistory', b'TrackLikelihood'), 0.5282592625879493),
#  ((b'RichAbovePiThres', b'TrackLikelihood'), 0.4717475007413141),
#  ((b'InAccMuon', b'InAccMuon'), 0.5278725225276931),
#  ((b'TrackGhostProbability', b'TrackLikelihood'), 0.5278698880580585),
#  ((b'CaloEcalE', b'TrackFitTNDoF'), 0.5273218696875173),
#  ((b'TrackGhostProbability', b'TrackGhostProbability'), 0.47270362244847597),
#  ((b'RichDLLmu', b'RichUsedR2Gas'), 0.5270328989205342),
#  ((b'CaloHcalE', b'TrackHistory'), 0.5267686666472909),
#  ((b'InAccMuon', b'TrackLikelihood'), 0.4744714697893975),
#  ((b'CaloHcalE', b'VeloCharge'), 0.524934158684706),
#  ((b'TrackFitTNDoF', b'TrackLikelihood'), 0.5247753317413721),
#  ((b'CaloEcalE', b'RichAbovePiThres'), 0.5247649047174449),
#  ((b'RichAbovePiThres', b'TrackHistory'), 0.52379104074254),
#  ((b'TrackLikelihood', b'VeloCharge'), 0.5232982560177346),
#  ((b'CaloEcalE', b'TrackLikelihood'), 0.4770636087211453),
#  ((b'CaloEcalE', b'InAccMuon'), 0.5228312639117229),
#  ((b'CaloEcalE', b'CaloHcalE'), 0.5221579566468874),
#  ((b'CaloEcalE', b'VeloCharge'), 0.5220930586129865),
#  ((b'CaloEcalE', b'CaloEcalE'), 0.5220149439498686),
#  ((b'CaloEcalE', b'TrackHistory'), 0.5217618514097653),
#  ((b'CaloHcalE', b'RichAbovePiThres'), 0.5215071094455128),
#  ((b'CaloEcalE', b'RichAbovePrThres'), 0.5214547759181771),
#  ((b'CaloHcalE', b'RichAbovePrThres'), 0.5214519283033293),
#  ((b'CaloHcalE', b'CaloHcalE'), 0.5209600224189028),
#  ((b'InAccMuon', b'TrackFitTNDoF'), 0.5207775409084135),
#  ((b'TrackHistory', b'TrackHistory'), 0.47939565211478674),
#  ((b'RichAbovePiThres', b'TrackFitTNDoF'), 0.5198023402511719),
#  ((b'RichAboveKaThres', b'RichDLLmu'), 0.4803819258531019),
#  ((b'InAccMuon', b'TrackHistory'), 0.5195870608798836),
#  ((b'CaloHcalE', b'TrackGhostProbability'), 0.5192561678294766),
#  ((b'TrackP', b'piplus_IP_OWNPV'), 0.5191832738260795),
#  ((b'RichAbovePiThres', b'TrackGhostProbability'), 0.5179275813133344),
#  ((b'CaloHcalE', b'InAccMuon'), 0.517919130346383),
#  ((b'TrackLikelihood', b'TrackLikelihood'), 0.4826390675433385),
#  ((b'RichAboveKaThres', b'RichDLLe'), 0.5148776716012965),
#  ((b'RichDLLk', b'RichDLLp'), 0.48632657806450375),
#  ((b'CaloEcalE', b'TrackGhostProbability'), 0.5118693310788297),
#  ((b'InAccMuon', b'TrackGhostProbability'), 0.5117909699799652),
#  ((b'InAccMuon', b'piplus_IP_OWNPV'), 0.488901162164196),
#  ((b'CaloHcalE', b'piplus_IP_OWNPV'), 0.5104599146983541),
#  ((b'RichAbovePiThres', b'piplus_IP_OWNPV'), 0.49180423150238717),
#  ((b'RichDLLbt', b'RichDLLp'), 0.49239126115494153),
#  ((b'RichDLLbt', b'RichDLLbt'), 0.5075344454927618),
#  ((b'RichAbovePiThres', b'VeloCharge'), 0.5054972326929635),
#  ((b'RichDLLbt', b'RichDLLk'), 0.4966935257873868),
#  ((b'CaloEcalE', b'piplus_IP_OWNPV'), 0.49806577035868904),
#  ((b'InAccMuon', b'VeloCharge'), 0.5013614991305563),
#  ((b'RichDLLp', b'RichDLLp'), 0.4996286221116065)]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import RobustScaler

# %%
def fit_n_score(feature_names):
    features = [get_feature(f) for f in feature_names]
    features += [get_feature(f1) * get_feature(f2) for f1, f2 in combwr(feature_names, 2)]
    
    features = np.array(features).T
    
    scaler = RobustScaler()
    scaler.fit(features)
    features = scaler.transform(features)
    
    model = LogisticRegression(solver='liblinear')
    
    model.fit(features, is_k)
    predictions = model.predict_proba(features)[:,1]
    
    return roc_auc_score(is_k, predictions)

# %%
scores_quad = {fnames : fit_n_score(fnames) for fnames, _ in tqdm(scores_2.items())}
# Out:
# HBox(children=(IntProgress(value=0, max=210), HTML(value='')))
# /mnt/amaevskiy/conda_env/lib/python3.7/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /mnt/amaevskiy/conda_env/lib/python3.7/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /mnt/amaevskiy/conda_env/lib/python3.7/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
sorted(scores_quad.items(), key=lambda x: -x[1])
# Out:
# [((b'RichDLLk', b'TrackP'), 0.9487246254039718),
#  ((b'RichDLLk', b'TrackPt'), 0.9484843004446368),
#  ((b'RichDLLe', b'RichDLLk'), 0.948304606360435),
#  ((b'RichDLLk', b'RichUsedR2Gas'), 0.9478605119398218),
#  ((b'RichDLLk', b'TrackFitTNDoF'), 0.9475994772562764),
#  ((b'RichAbovePrThres', b'RichDLLk'), 0.9475208454636412),
#  ((b'CaloHcalE', b'RichDLLk'), 0.9472042402945231),
#  ((b'InAccMuon', b'RichDLLk'), 0.9471495621268424),
#  ((b'RichAbovePiThres', b'RichDLLk'), 0.94709094217322),
#  ((b'CaloEcalE', b'RichDLLk'), 0.9470723561181331),
#  ((b'RichDLLk', b'TrackHistory'), 0.9467992307129962),
#  ((b'RichDLLbt', b'RichDLLk'), 0.9467829053596701),
#  ((b'RichDLLk', b'RichDLLmu'), 0.9467506428959063),
#  ((b'RichDLLk', b'RichDLLp'), 0.9467321472804102),
#  ((b'RichDLLk', b'TrackLikelihood'), 0.9466285561348147),
#  ((b'RichDLLk', b'VeloCharge'), 0.9465583323100877),
#  ((b'RichAboveKaThres', b'RichDLLk'), 0.9465198624256165),
#  ((b'RichDLLk', b'TrackGhostProbability'), 0.9462770291567729),
#  ((b'RichDLLk', b'RichDLLk'), 0.9460565636097982),
#  ((b'RichDLLk', b'piplus_IP_OWNPV'), 0.9336538246220382),
#  ((b'RichAbovePrThres', b'RichDLLp'), 0.9227577486915046),
#  ((b'RichAbovePrThres', b'RichDLLbt'), 0.9227176631434175),
#  ((b'RichDLLbt', b'TrackP'), 0.9218173661435825),
#  ((b'RichDLLp', b'TrackPt'), 0.9199212764104132),
#  ((b'RichDLLbt', b'TrackPt'), 0.9194972632603823),
#  ((b'RichAboveKaThres', b'RichDLLbt'), 0.9182655733681404),
#  ((b'RichAboveKaThres', b'RichDLLp'), 0.9176212901988304),
#  ((b'RichDLLbt', b'RichDLLe'), 0.9149140528594791),
#  ((b'RichDLLp', b'TrackP'), 0.9141731708460662),
#  ((b'RichDLLbt', b'RichDLLp'), 0.9132137662156209),
#  ((b'RichDLLe', b'RichDLLp'), 0.9127385553523902),
#  ((b'RichDLLbt', b'RichUsedR2Gas'), 0.9126335328108636),
#  ((b'RichDLLp', b'RichUsedR2Gas'), 0.9113810615683394),
#  ((b'RichDLLbt', b'RichDLLmu'), 0.9076552105323321),
#  ((b'RichDLLbt', b'piplus_IP_OWNPV'), 0.9061746341216935),
#  ((b'RichDLLbt', b'TrackFitTNDoF'), 0.9058941075476551),
#  ((b'CaloHcalE', b'RichDLLbt'), 0.9058106996837437),
#  ((b'RichAbovePiThres', b'RichDLLbt'), 0.9053121181271412),
#  ((b'CaloEcalE', b'RichDLLbt'), 0.905127088608604),
#  ((b'RichDLLmu', b'RichDLLp'), 0.9050772960713094),
#  ((b'InAccMuon', b'RichDLLbt'), 0.90466576393576),
#  ((b'RichDLLbt', b'TrackLikelihood'), 0.9042831576176374),
#  ((b'RichDLLbt', b'TrackHistory'), 0.9042140427250195),
#  ((b'CaloHcalE', b'RichDLLp'), 0.9038412651512264),
#  ((b'RichDLLbt', b'VeloCharge'), 0.9037082389941947),
#  ((b'RichDLLp', b'piplus_IP_OWNPV'), 0.9034804288433752),
#  ((b'RichDLLbt', b'TrackGhostProbability'), 0.9034770042374501),
#  ((b'RichAbovePiThres', b'RichDLLp'), 0.9032065359584709),
#  ((b'RichDLLp', b'TrackFitTNDoF'), 0.903130532437964),
#  ((b'RichDLLbt', b'RichDLLbt'), 0.9031100630059936),
#  ((b'CaloEcalE', b'RichDLLp'), 0.9029509021308262),
#  ((b'InAccMuon', b'RichDLLp'), 0.9019391433375248),
#  ((b'RichDLLp', b'TrackLikelihood'), 0.9015182945446583),
#  ((b'RichDLLp', b'TrackHistory'), 0.9015064550958183),
#  ((b'RichDLLp', b'VeloCharge'), 0.9007095966579263),
#  ((b'RichDLLp', b'TrackGhostProbability'), 0.900665388025716),
#  ((b'RichDLLp', b'RichDLLp'), 0.9001712651310723),
#  ((b'RichDLLe', b'TrackPt'), 0.7770972038488422),
#  ((b'RichAbovePiThres', b'RichDLLe'), 0.7699350558948933),
#  ((b'RichDLLe', b'TrackFitTNDoF'), 0.7683793875446596),
#  ((b'RichDLLe', b'piplus_IP_OWNPV'), 0.7680072381954944),
#  ((b'RichAboveKaThres', b'RichDLLe'), 0.7652006765983151),
#  ((b'RichDLLe', b'RichUsedR2Gas'), 0.7644739516090593),
#  ((b'CaloHcalE', b'RichDLLe'), 0.7644350526311587),
#  ((b'RichDLLe', b'VeloCharge'), 0.7638976228012065),
#  ((b'RichDLLe', b'TrackP'), 0.7634757356198016),
#  ((b'RichDLLe', b'TrackGhostProbability'), 0.7628868811559223),
#  ((b'InAccMuon', b'RichDLLe'), 0.7622067374867505),
#  ((b'RichDLLe', b'TrackLikelihood'), 0.7616795557405461),
#  ((b'RichDLLe', b'TrackHistory'), 0.7615892157147023),
#  ((b'CaloEcalE', b'RichDLLe'), 0.7615661269806127),
#  ((b'RichAbovePrThres', b'RichDLLe'), 0.7608680992330555),
#  ((b'RichDLLe', b'RichDLLe'), 0.7603693584012942),
#  ((b'RichDLLe', b'RichDLLmu'), 0.7590077982611764),
#  ((b'RichDLLmu', b'TrackPt'), 0.7252167437482027),
#  ((b'RichAbovePiThres', b'RichDLLmu'), 0.7076267731484933),
#  ((b'InAccMuon', b'RichDLLmu'), 0.6934876817158082),
#  ((b'RichAbovePrThres', b'RichDLLmu'), 0.6889275581119932),
#  ((b'RichDLLmu', b'TrackP'), 0.6878183814397697),
#  ((b'RichAboveKaThres', b'RichDLLmu'), 0.6868547711321191),
#  ((b'RichDLLmu', b'RichUsedR2Gas'), 0.685882419975727),
#  ((b'RichDLLmu', b'TrackFitTNDoF'), 0.6828432282109077),
#  ((b'RichDLLmu', b'TrackGhostProbability'), 0.6823560947582535),
#  ((b'RichDLLmu', b'VeloCharge'), 0.6822392575259117),
#  ((b'CaloEcalE', b'RichDLLmu'), 0.6793867129012472),
#  ((b'RichDLLmu', b'TrackLikelihood'), 0.6789457829417986),
#  ((b'RichDLLmu', b'TrackHistory'), 0.6764099914644006),
#  ((b'CaloHcalE', b'RichDLLmu'), 0.6763866040570123),
#  ((b'RichDLLmu', b'RichDLLmu'), 0.6759061094059976),
#  ((b'RichDLLmu', b'piplus_IP_OWNPV'), 0.6715209498626536),
#  ((b'TrackPt', b'VeloCharge'), 0.6547403765878755),
#  ((b'TrackP', b'TrackPt'), 0.6541653858018607),
#  ((b'TrackPt', b'piplus_IP_OWNPV'), 0.6521598746092651),
#  ((b'RichAbovePiThres', b'TrackPt'), 0.6516515037408731),
#  ((b'RichAboveKaThres', b'TrackPt'), 0.6507231331164633),
#  ((b'RichUsedR2Gas', b'TrackPt'), 0.6507063512121807),
#  ((b'InAccMuon', b'TrackPt'), 0.6501843711651788),
#  ((b'RichAbovePrThres', b'TrackPt'), 0.6501091208734256),
#  ((b'TrackPt', b'TrackPt'), 0.6498611919684861),
#  ((b'CaloEcalE', b'TrackPt'), 0.6498562430525371),
#  ((b'CaloHcalE', b'TrackPt'), 0.6498466315079253),
#  ((b'TrackLikelihood', b'TrackPt'), 0.6495266950269751),
#  ((b'TrackFitTNDoF', b'TrackPt'), 0.6493660919303653),
#  ((b'TrackGhostProbability', b'TrackPt'), 0.6493391162133885),
#  ((b'TrackHistory', b'TrackPt'), 0.6491105928908556),
#  ((b'TrackP', b'piplus_IP_OWNPV'), 0.6259761464564375),
#  ((b'CaloHcalE', b'TrackP'), 0.622187455504087),
#  ((b'RichAboveKaThres', b'TrackP'), 0.6213618482969456),
#  ((b'RichAbovePiThres', b'TrackP'), 0.6206264660975326),
#  ((b'TrackP', b'VeloCharge'), 0.620097964841509),
#  ((b'TrackP', b'TrackP'), 0.6193229535084651),
#  ((b'TrackLikelihood', b'TrackP'), 0.6192470044650129),
#  ((b'TrackFitTNDoF', b'TrackP'), 0.6182699410794082),
#  ((b'CaloEcalE', b'TrackP'), 0.617267853560279),
#  ((b'RichUsedR2Gas', b'TrackP'), 0.6170921635770815),
#  ((b'TrackGhostProbability', b'TrackP'), 0.6164919729838658),
#  ((b'TrackHistory', b'TrackP'), 0.6160213784607516),
#  ((b'InAccMuon', b'TrackP'), 0.6148213950902177),
#  ((b'RichAboveKaThres', b'piplus_IP_OWNPV'), 0.6144317596305656),
#  ((b'RichAboveKaThres', b'VeloCharge'), 0.6089012139997878),
#  ((b'RichAboveKaThres', b'RichAbovePiThres'), 0.6004628718380913),
#  ((b'RichUsedR2Gas', b'piplus_IP_OWNPV'), 0.599193657766324),
#  ((b'RichAbovePrThres', b'piplus_IP_OWNPV'), 0.5986117583784002),
#  ((b'InAccMuon', b'RichAboveKaThres'), 0.5979956346672505),
#  ((b'RichAboveKaThres', b'RichUsedR2Gas'), 0.5966168693834273),
#  ((b'RichAboveKaThres', b'RichAbovePrThres'), 0.5961082025732392),
#  ((b'RichAboveKaThres', b'TrackFitTNDoF'), 0.59606640517044),
#  ((b'RichAboveKaThres', b'TrackGhostProbability'), 0.5954353870253951),
#  ((b'CaloEcalE', b'RichAboveKaThres'), 0.5926728188997112),
#  ((b'RichAboveKaThres', b'TrackHistory'), 0.5917521560880097),
#  ((b'RichAboveKaThres', b'TrackLikelihood'), 0.5913073949112299),
#  ((b'RichAbovePrThres', b'RichUsedR2Gas'), 0.5900155846733652),
#  ((b'RichAboveKaThres', b'RichAboveKaThres'), 0.5879837296084249),
#  ((b'CaloHcalE', b'RichAboveKaThres'), 0.587801113358301),
#  ((b'RichUsedR2Gas', b'VeloCharge'), 0.5875653460815238),
#  ((b'RichAbovePrThres', b'VeloCharge'), 0.5871694497946109),
#  ((b'RichAbovePiThres', b'RichAbovePrThres'), 0.5817477687167021),
#  ((b'RichUsedR2Gas', b'TrackGhostProbability'), 0.5793638460416793),
#  ((b'RichAbovePiThres', b'piplus_IP_OWNPV'), 0.5792262009795285),
#  ((b'RichAbovePiThres', b'RichUsedR2Gas'), 0.579059391480712),
#  ((b'CaloHcalE', b'RichUsedR2Gas'), 0.5784843274511239),
#  ((b'InAccMuon', b'RichAbovePrThres'), 0.5781455362223182),
#  ((b'RichUsedR2Gas', b'TrackFitTNDoF'), 0.5775642765815343),
#  ((b'InAccMuon', b'RichUsedR2Gas'), 0.577285885893632),
#  ((b'RichUsedR2Gas', b'TrackLikelihood'), 0.5750849218140754),
#  ((b'CaloEcalE', b'RichUsedR2Gas'), 0.573483413666),
#  ((b'CaloEcalE', b'RichAbovePrThres'), 0.5725474859555328),
#  ((b'RichAbovePrThres', b'TrackGhostProbability'), 0.5724567183912617),
#  ((b'RichAbovePrThres', b'TrackFitTNDoF'), 0.5719072186647389),
#  ((b'RichUsedR2Gas', b'TrackHistory'), 0.5716727625617728),
#  ((b'CaloHcalE', b'RichAbovePrThres'), 0.570058741581184),
#  ((b'InAccMuon', b'piplus_IP_OWNPV'), 0.5695061711185905),
#  ((b'RichUsedR2Gas', b'RichUsedR2Gas'), 0.5692100279144348),
#  ((b'RichAbovePrThres', b'TrackHistory'), 0.5674735737844077),
#  ((b'RichAbovePiThres', b'VeloCharge'), 0.5644243473020532),
#  ((b'RichAbovePrThres', b'TrackLikelihood'), 0.5643699698301733),
#  ((b'VeloCharge', b'piplus_IP_OWNPV'), 0.5636107277943994),
#  ((b'TrackHistory', b'piplus_IP_OWNPV'), 0.5617777679108626),
#  ((b'TrackGhostProbability', b'piplus_IP_OWNPV'), 0.5608146046091589),
#  ((b'piplus_IP_OWNPV', b'piplus_IP_OWNPV'), 0.5601554491299757),
#  ((b'TrackLikelihood', b'piplus_IP_OWNPV'), 0.5591366806511644),
#  ((b'RichAbovePrThres', b'RichAbovePrThres'), 0.5585727169466771),
#  ((b'CaloHcalE', b'piplus_IP_OWNPV'), 0.5585241656576239),
#  ((b'CaloEcalE', b'piplus_IP_OWNPV'), 0.5571869148243166),
#  ((b'TrackFitTNDoF', b'piplus_IP_OWNPV'), 0.5566791767845575),
#  ((b'InAccMuon', b'VeloCharge'), 0.5547683882086885),
#  ((b'RichAbovePiThres', b'TrackGhostProbability'), 0.5517968019494776),
#  ((b'CaloEcalE', b'TrackFitTNDoF'), 0.5513674810401383),
#  ((b'RichAbovePiThres', b'TrackFitTNDoF'), 0.5509070592616974),
#  ((b'TrackFitTNDoF', b'VeloCharge'), 0.5465477418121969),
#  ((b'CaloHcalE', b'TrackFitTNDoF'), 0.5465051710341242),
#  ((b'CaloEcalE', b'VeloCharge'), 0.5464428291772797),
#  ((b'RichAbovePiThres', b'TrackHistory'), 0.5461281774156148),
#  ((b'InAccMuon', b'TrackFitTNDoF'), 0.5460852209796564),
#  ((b'CaloHcalE', b'VeloCharge'), 0.5458265341429589),
#  ((b'InAccMuon', b'TrackGhostProbability'), 0.5449941253345153),
#  ((b'TrackLikelihood', b'VeloCharge'), 0.5425526763479638),
#  ((b'CaloEcalE', b'RichAbovePiThres'), 0.5419316223558834),
#  ((b'RichAbovePiThres', b'TrackLikelihood'), 0.5416292868560353),
#  ((b'TrackHistory', b'VeloCharge'), 0.5414304567306968),
#  ((b'InAccMuon', b'RichAbovePiThres'), 0.5410770629497881),
#  ((b'TrackGhostProbability', b'VeloCharge'), 0.5406080010682065),
#  ((b'CaloHcalE', b'RichAbovePiThres'), 0.5405472026909057),
#  ((b'TrackFitTNDoF', b'TrackGhostProbability'), 0.5391111972843399),
#  ((b'CaloHcalE', b'TrackGhostProbability'), 0.5381738702524737),
#  ((b'CaloEcalE', b'CaloHcalE'), 0.5375896408087196),
#  ((b'InAccMuon', b'TrackHistory'), 0.5373847419483121),
#  ((b'CaloEcalE', b'TrackGhostProbability'), 0.5370567600968165),
#  ((b'TrackFitTNDoF', b'TrackLikelihood'), 0.5368791800202289),
#  ((b'TrackGhostProbability', b'TrackHistory'), 0.5368581157386637),
#  ((b'CaloEcalE', b'TrackHistory'), 0.5364397836133141),
#  ((b'CaloHcalE', b'TrackHistory'), 0.535937208626218),
#  ((b'CaloEcalE', b'TrackLikelihood'), 0.535927065177074),
#  ((b'CaloEcalE', b'InAccMuon'), 0.5351407053051812),
#  ((b'RichAbovePiThres', b'RichAbovePiThres'), 0.5348494285128922),
#  ((b'TrackFitTNDoF', b'TrackHistory'), 0.5347839844234454),
#  ((b'CaloHcalE', b'TrackLikelihood'), 0.5342408277047658),
#  ((b'VeloCharge', b'VeloCharge'), 0.5330350329749205),
#  ((b'InAccMuon', b'TrackLikelihood'), 0.531575510853837),
#  ((b'CaloHcalE', b'InAccMuon'), 0.5307708507621431),
#  ((b'TrackHistory', b'TrackLikelihood'), 0.5305265676433497),
#  ((b'TrackFitTNDoF', b'TrackFitTNDoF'), 0.528881781923995),
#  ((b'InAccMuon', b'InAccMuon'), 0.5278725225276931),
#  ((b'TrackGhostProbability', b'TrackGhostProbability'), 0.5272626182107633),
#  ((b'TrackGhostProbability', b'TrackLikelihood'), 0.5267853285624536),
#  ((b'CaloHcalE', b'CaloHcalE'), 0.5257371064461874),
#  ((b'CaloEcalE', b'CaloEcalE'), 0.5237342223167191),
#  ((b'TrackHistory', b'TrackHistory'), 0.5206043478852133),
#  ((b'TrackLikelihood', b'TrackLikelihood'), 0.5173609320126613),
#  ((b'RichAbovePrThres', b'TrackP'), 0.5084522929121478)]
